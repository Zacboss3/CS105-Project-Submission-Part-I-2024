# %%
import pandas as pd
import numpy as np

# %%
housing_df = pd.read_csv('./data/housing.csv')
housing_df.head()
# Out:
#    ID Crime_Rate Residential_Area  Non_Retail River  Pollutants  Rooms  \
# 0   1        Low         Very Low        2.31   Far       0.538  6.575
# 1   2        Low         Very Low        7.07   Far       0.469  6.421
# 2   3        Low         Very Low        7.07   Far       0.469  7.185
# 3   4        Low         Very Low        2.18   Far       0.458  6.998
# 4   5        Low         Very Low        2.18   Far       0.458  7.147
#
#    Old_Housing  Distance_Office Highway_Access  Tax_Rate  \
# 0         65.2           4.0900            Low       296
# 1         78.9           4.9671            Low       242
# 2         61.1           4.9671            Low       242
# 3         45.8           6.0622            Low       222
# 4         54.2           6.0622            Low       222
#
#    Student_Teacher_Ratio  Low_Income  Price
# 0                   15.3        4.98   24.0
# 1                   17.8        9.14   21.6
# 2                   17.8        4.03   34.7
# ...

# %%
housing_df.shape
# Out:
# (506, 14)

# %%
housing_df.describe().T
# Out:
#                        count        mean         std       min         25%  \
# ID                     506.0  253.500000  146.213884    1.0000  127.250000
# Non_Retail             506.0   11.136779    6.860353    0.4600    5.190000
# Pollutants             506.0    0.554695    0.115878    0.3850    0.449000
# Rooms                  476.0    6.278624    0.689784    3.5610    5.879750
# Old_Housing            506.0   69.124506   28.346261    2.9000   45.175000
# Distance_Office        506.0    3.795262    2.105850    1.1296    2.100175
# Tax_Rate               506.0  408.237154  168.537116  187.0000  279.000000
# Student_Teacher_Ratio  506.0   18.452174    2.165144   12.6000   17.325000
# Low_Income             506.0   12.653063    7.141062    1.7300    6.950000
# Price                  506.0   22.532806    9.197104    5.0000   17.025000
#
#                              50%         75%       max
# ID                     253.50000  379.750000  506.0000
# ...

# %%
housing_df.isnull().sum()
# Out:
# ID                        0
# Crime_Rate                0
# Residential_Area         28
# Non_Retail                0
# River                     0
# Pollutants                0
# Rooms                    30
# Old_Housing               0
# Distance_Office           0
# Highway_Access            0
# Tax_Rate                  0
# Student_Teacher_Ratio     0
# Low_Income                0
# Price                     0
# dtype: int64

# %%
housing_corr = housing_df.corr()
housing_corr
# Out:
#                              ID  Non_Retail  Pollutants     Rooms  \
# ID                     1.000000    0.399439    0.398736 -0.080498
# Non_Retail             0.399439    1.000000    0.763651 -0.383212
# Pollutants             0.398736    0.763651    1.000000 -0.294774
# Rooms                 -0.080498   -0.383212   -0.294774  1.000000
# Old_Housing            0.212037    0.642360    0.721221 -0.230966
# Distance_Office       -0.302133   -0.707858   -0.769110  0.199001
# Tax_Rate               0.666626    0.720760    0.668023 -0.283840
# Student_Teacher_Ratio  0.291266    0.382773    0.188753 -0.343208
# Low_Income             0.258465    0.603800    0.590879 -0.614734
# Price                 -0.226604   -0.483725   -0.427321  0.692216
#
#                        Old_Housing  Distance_Office  Tax_Rate  \
# ID                        0.212037        -0.302133  0.666626
# Non_Retail                0.642360        -0.707858  0.720760
# ...

# %%
auto_df = pd.read_csv('./data/auto.csv')
auto_df.head()
# Out:
#    Risk_Rating         Make Fuel_Type Aspiration Doors         Body  \
# 0            3  Alfa-Romero       Gas        Std   Two  Convertible
# 1            3  Alfa-Romero       Gas        Std   Two  Convertible
# 2            2  Alfa-Romero       Gas        Std   Two    Hatchback
# 3            3         Audi       Gas        Std  Four        Sedan
# 4            3         Audi       Gas        Std  Four        Sedan
#
#   Drive_Wheels Engine_Loc  Wheel_Base  Length  ...  Engine_Size  Fuel_System  \
# 0          RWD      Front        88.6   168.8  ...          130         MPFI
# 1          RWD      Front        88.6   168.8  ...          130         MPFI
# 2          RWD      Front        94.5   171.2  ...          152         MPFI
# 3          FWD      Front        99.8   176.6  ...          109         MPFI
# 4          4WD      Front        99.4   176.6  ...          136         MPFI
#
#    Bore Stroke Compression_Ratio  Horsepower Peak_RPM  City_MPG  Highway_MPG  \
# ...

# %%
auto_df.shape
# Out:
# (201, 25)

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Risk_Rating        201 non-null    int64
#  1   Make               201 non-null    object
#  2   Fuel_Type          201 non-null    object
#  3   Aspiration         201 non-null    object
#  4   Doors              187 non-null    object
#  5   Body               201 non-null    object
#  6   Drive_Wheels       191 non-null    object
#  7   Engine_Loc         201 non-null    object
#  8   Wheel_Base         201 non-null    float64
#  9   Length             201 non-null    float64
#  10  Width              201 non-null    float64
#  11  Height             201 non-null    float64
#  12  Curb_Weight        201 non-null    int64
#  13  Engine_Type        201 non-null    object
#  14  Num_Of_Cylinders   196 non-null    object
#  15  Engine_Size        201 non-null    int64
# ...

# %%
auto_corr = auto_df.corr()
auto_corr
# Out:
#                    Risk_Rating  Wheel_Base    Length     Width    Height  \
# Risk_Rating           1.000000   -0.472436 -0.308035 -0.239368 -0.436179
# Wheel_Base           -0.472436    1.000000  0.875619  0.814548  0.583923
# Length               -0.308035    0.875619  1.000000  0.857170  0.492063
# Width                -0.239368    0.814548  0.857170  1.000000  0.306002
# Height               -0.436179    0.583923  0.492063  0.306002  1.000000
# Curb_Weight          -0.198764    0.783832  0.880665  0.866201  0.307581
# Engine_Size          -0.095195    0.575419  0.685025  0.729436  0.074694
# Bore                 -0.064424    0.486493  0.608616  0.544520  0.180608
# Stroke               -0.033786    0.169953  0.122081  0.188228 -0.067538
# Compression_Ratio    -0.126294    0.247659  0.159733  0.189867  0.259737
# Horsepower            0.032334    0.377356  0.579493  0.614841 -0.086878
# Peak_RPM              0.200718   -0.348017 -0.286517 -0.245862 -0.311713
# ...

# %%
auto_df.describe().T
# Out:
#                    count          mean          std      min      25%  \
# Risk_Rating        201.0      2.169154     0.625495     1.00     2.00
# Wheel_Base         201.0     98.769154     6.158096    86.60    94.50
# Length             201.0    174.200995    12.322175   141.10   166.80
# Width              201.0     65.889055     2.101471    60.30    64.10
# Height             201.0     53.766667     2.447822    47.80    52.00
# Curb_Weight        201.0   2555.666667   517.296727  1488.00  2169.00
# Engine_Size        201.0    126.875622    41.546834    61.00    98.00
# Bore               201.0      3.330647     0.268259     2.54     3.15
# Stroke             201.0      3.258159     0.316427     2.07     3.11
# Compression_Ratio  201.0     10.164279     4.004965     7.00     8.60
# Horsepower         201.0    103.378109    37.366112    48.00    70.00
# Peak_RPM           201.0   5117.412935   478.220946  4150.00  4800.00
# ...

# %%
auto_df.isnull().sum()
# Out:
# Risk_Rating           0
# Make                  0
# Fuel_Type             0
# Aspiration            0
# Doors                14
# Body                  0
# Drive_Wheels         10
# Engine_Loc            0
# Wheel_Base            0
# Length                0
# Width                 0
# Height                0
# Curb_Weight           0
# Engine_Type           0
# Num_Of_Cylinders      5
# Engine_Size           0
# Fuel_System           8
# Bore                  0
# Stroke                0
# Compression_Ratio     0
# Horsepower            0
# Peak_RPM              0
# City_MPG              0
# Highway_MPG           0
# Price                 0
# dtype: int64

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Risk_Rating        201 non-null    int64
#  1   Make               201 non-null    object
#  2   Fuel_Type          201 non-null    object
#  3   Aspiration         201 non-null    object
#  4   Doors              187 non-null    object
#  5   Body               201 non-null    object
#  6   Drive_Wheels       191 non-null    object
#  7   Engine_Loc         201 non-null    object
#  8   Wheel_Base         201 non-null    float64
#  9   Length             201 non-null    float64
#  10  Width              201 non-null    float64
#  11  Height             201 non-null    float64
#  12  Curb_Weight        201 non-null    int64
#  13  Engine_Type        201 non-null    object
#  14  Num_Of_Cylinders   196 non-null    object
#  15  Engine_Size        201 non-null    int64
# ...

# %%
auto_df['Fuel_System'].unique()
# Out:
# array(['MPFI', '2BBL', 'MFI', '1BBL', nan, 'SPFI', '4BBL', 'IDI', 'SPDI'],
#       dtype=object)

# %%
auto_df['Fuel_System'].mode()
# Out:
# 0    MPFI
# Name: Fuel_System, dtype: object

# %%
wine_df = pd.read_csv('./data/wine.csv')
wine_df.head()
# Out:
#    ID  Fixed_Acidity  Volatile_Acidity  Citric_Acid Residual_Sugar  Chlorides  \
# 0   1            7.0              0.27         0.36           High      0.045
# 1   2            6.3              0.30         0.34            Low      0.049
# 2   3            8.1              0.28         0.40            Low      0.050
# 3   4            7.2              0.23         0.32       Moderate      0.058
# 4   5            7.2              0.23         0.32       Moderate      0.058
#
#    Free_SO2  Total_SO2    Density      pH  Sulphates Alcohol  Quality
# 0      45.0      170.0      >1.00  Acidic       0.45      8%        6
# 1      14.0      132.0  0.99-1.00  Acidic       0.49      9%        6
# 2      30.0       97.0  0.99-1.00  Acidic       0.44     10%        6
# 3      47.0      186.0  0.99-1.00  Acidic       0.40      9%        6
# 4      47.0      186.0  0.99-1.00  Acidic       0.40      9%        6

# %%
wine_df.shape
# Out:
# (4898, 13)

# %%
wine_df.describe().T
# Out:
#                    count         mean          std    min       25%       50%  \
# ID                4898.0  2449.500000  1414.075139  1.000  1225.250  2449.500
# Fixed_Acidity     4680.0     6.851143     0.841314  3.800     6.300     6.800
# Volatile_Acidity  4848.0     0.277986     0.100726  0.080     0.210     0.260
# Citric_Acid       4898.0     0.334136     0.120969  0.000     0.270     0.320
# Chlorides         4898.0     0.045772     0.021848  0.009     0.036     0.043
# Free_SO2          4898.0    35.308085    17.007137  2.000    23.000    34.000
# Total_SO2         4898.0   137.346264    43.564766  6.000   107.000   134.000
# Sulphates         4898.0     0.489822     0.114144  0.220     0.410     0.470
# Quality           4898.0     5.877909     0.885639  3.000     5.000     6.000
#
#                       75%       max
# ID                3673.75  4898.000
# Fixed_Acidity        7.30    14.200
# Volatile_Acidity     0.32     1.100
# Citric_Acid          0.39     1.660
# ...

# %%
wine_df.isnull().sum()
# Out:
# ID                    0
# Fixed_Acidity       218
# Volatile_Acidity     50
# Citric_Acid           0
# Residual_Sugar        0
# Chlorides             0
# Free_SO2              0
# Total_SO2             0
# Density             224
# pH                    0
# Sulphates             0
# Alcohol               0
# Quality               0
# dtype: int64

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                4898 non-null   int64
#  1   Fixed_Acidity     4680 non-null   float64
#  2   Volatile_Acidity  4848 non-null   float64
#  3   Citric_Acid       4898 non-null   float64
#  4   Residual_Sugar    4898 non-null   object
#  5   Chlorides         4898 non-null   float64
#  6   Free_SO2          4898 non-null   float64
#  7   Total_SO2         4898 non-null   float64
#  8   Density           4674 non-null   object
#  9   pH                4898 non-null   object
#  10  Sulphates         4898 non-null   float64
#  11  Alcohol           4898 non-null   object
#  12  Quality           4898 non-null   int64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 497.6+ KB

# %%
wine_df.sample(10)
# Out:
#         ID  Fixed_Acidity  Volatile_Acidity  Citric_Acid Residual_Sugar  \
# 4088  4089            7.3              0.25         0.27            Low
# 3188  3189            7.0              0.17         0.36            Low
# 543    544            6.7              0.24         0.41       Moderate
# 3336  3337            6.9              0.38         0.30           High
# 2381  2382            7.0              0.23         0.42            Low
# 420    421            7.0              0.22         0.31            Low
# 1052  1053            7.6              0.29         0.42            Low
# 1246  1247            8.0               NaN         0.40            Low
# 4339  4340            6.8              0.24         0.29            Low
# 4666  4667            6.4              0.31         0.53       Moderate
#
#       Chlorides  Free_SO2  Total_SO2    Density             pH  Sulphates  \
# 4088      0.047      16.0       79.0  0.99-1.00         Acidic       0.46
# ...

# %%
wine_df['pH'].unique()
# Out:
# array(['Acidic', 'Highly Acidic', 'Neutral'], dtype=object)

# %%
wine_corr = wine_df.corr()
wine_corr
# Out:
#                         ID  Fixed_Acidity  Volatile_Acidity  Citric_Acid  \
# ID                1.000000      -0.258180          0.005007    -0.149836
# Fixed_Acidity    -0.258180       1.000000         -0.020368     0.287692
# Volatile_Acidity  0.005007      -0.020368          1.000000    -0.150004
# Citric_Acid      -0.149836       0.287692         -0.150004     1.000000
# Chlorides        -0.045645       0.023441          0.070187     0.113768
# Free_SO2         -0.011929      -0.041856         -0.095984     0.094329
# Total_SO2        -0.158212       0.096556          0.085094     0.119169
# Sulphates         0.009395      -0.014732         -0.036076     0.062529
# Quality           0.035763      -0.113064         -0.194081    -0.008895
#
#                   Chlorides  Free_SO2  Total_SO2  Sulphates   Quality
# ID                -0.045645 -0.011929  -0.158212   0.009395  0.035763
# Fixed_Acidity      0.023441 -0.041856   0.096556  -0.014732 -0.113064
# ...
